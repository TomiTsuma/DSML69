# %%
import psycopg2
import pandas as pd
import ast
import numpy as np
import pickle
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from pathlib import Path
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from ray import train, tune, data, serve
from sklearn.ensemble import RandomForestClassifier

# %%
r = robjects.r
r['source']('D://Cropnuts/DSML155/splits.R')
split = robjects.globalenv['split']
# Out:
# R[write to console]: prospectr version 0.2.7 -- cakes
#
# R[write to console]: check the package repository at: https://github.com/l-ramirez-lopez/prospectr
#
# R[write to console]: data.table 1.15.4 using 6 threads (see ?getDTthreads).
# R[write to console]: Latest news: r-datatable.com
#
# R[write to console]: Use suppressPackageStartupMessages() to eliminate package startup
# messages
#
# R[write to console]: terra 1.7.78
#
# R[write to console]:
# Attaching package: 'terra'
#
#
# R[write to console]: The following object is masked from 'package:data.table':
#
#     shift
#
#
# R[write to console]: The following object is masked from 'package:prospectr':
#
#     resample

# %%
def get_db_cursor():
    username = "doadmin"
    password = 'yzmodwh2oh16iks6'
    host = 'db-postgresql-cl1-do-user-2276924-0.db.ondigitalocean.com'
    port = 25060
    database = 'MandatoryMetadata'
    schema = 'testing'

    conn = psycopg2.connect(host=host, database=database,
                            user=username, password=password, port=port)
    cur = conn.cursor()
    cur.execute("SET search_path TO " + schema)

    return conn, cur

# %%
conn,cur = get_db_cursor()

# %%
def convertSpectra(df):
    print("Converting spectra")
    df_ = pd.DataFrame([i[[i for i in i.keys()][0]] for i in df['averaged_spectra'].values],columns = np.arange(522,3977,2))
    df_.index = df.index
    print("Spectra converted")
    return df_

# %%
def getValidAver(sample_codes, subset_count=None, filename="spectraldata"):
    conn, cur = get_db_cursor()
    spectra = pd.DataFrame(columns=['sample_code','averaged_spectra'])
    # count = len(sample_codes)
    if(len(sample_codes) < 5000):
        count  = len(sample_codes)
        step=count
    elif(len(sample_codes) < 70000):
        count = len(sample_codes)
        step=5000
    else:
        count = 100000
        step=5000
    start = 0

    for i in np.arange(start, count, step):
        
        print("Fetching spectra from {}".format(start))
        samples = [i for i in sample_codes][start:start+step]
        query = f"SELECT spectraldata.metadata_id, averaged_spectra, mandatorymetadata.sample_code  FROM spectraldata INNER JOIN mandatorymetadata ON mandatorymetadata.metadata_id = spectraldata.metadata_id WHERE is_finalized=True AND passed=True AND is_active=True AND averaged=True AND sample_code IN {str(samples).replace('[','(').replace(']',')')}"
        
        _ = pd.read_sql(query, con=conn)
        spectra = pd.concat([spectra, _], axis=0)
        start = start + step
        if (count-step) > 5000:
            step=5000
        else:
            step = count-step

    conn.close()
    spectra = spectra[['sample_code', 'averaged_spectra']]
    spectra = spectra.set_index('sample_code')
    spectra = convertSpectra(spectra)


    spectra.to_csv(f"input/{filename}.csv")

    return spectra

# %%
def getSampleCodes():
    df = pd.read_sql("""
        select m.sample_code, f.validated_subtype from fertilizercomments f 
        inner join spectraldata s 
        on s.spectral_data_id = f.spectral_data_id 
        inner join mandatorymetadata m 
        on m.metadata_id = s.metadata_id 
        where f.has_validated_subtype = true 
    """,con=conn)
    return df

# %%
def getCategory(value, lower, median, upper):
        if (value <= lower):
            return 1
        elif (value <= median):
            return 2
        elif (value <= upper):
            return 3
        else:
            return 4

# %%
def hyperparamTuning(X_valid, X_test, y_valid, y_test):
    search_space = {
        "n_estimators": tune.choice([50, 100, 150, 200, 250]),
        "max_depth": tune.choice([None, 10, 20, 30, 40 ,50, 60]),
        "min_samples_split": tune.choice([2, 5, 10, 12,15,20,32,36,40]),
        "criterion": tune.choice(["gini", "entropy", "log_loss"]),
        "min_samples_leaf": tune.randint(1, 15),
        "max_features": tune.choice(["sqrt", "log2", None]),
        "X_valid": X_valid,
        "X_test": X_test,
        "y_valid": y_valid,
        "y_test": y_test,
    }
    analysis = tune.run(
        trainRF,
        config=search_space,
        metric="accuracy",
        mode="max",
        num_samples=200,
    )

    

    best_config = analysis.get_best_config(metric="accuracy", mode="max")

    del best_config['X_valid']
    del best_config['y_valid']
    del best_config['X_test']
    del best_config['y_test']

    return best_config

# %%
def trainRF(config):
    valid_features = config['X_valid']
    valid_target = config['y_valid']
    test_features = config['X_test']
    test_target = config['y_test']
    del config['X_valid']
    del config['y_valid']
    del config['X_test']
    del config['y_test']
    model = RandomForestClassifier(**config)
    model.fit(valid_features, valid_target)
    score = model.score(test_features, test_target)
    return {'accuracy': score}

# %%
def trainRFClassifier(best_config, X_train, y_train):
    rf = RandomForestClassifier(**best_config)
    rf.fit(X_train, y_train)

    pickle.dump(rf, open("output/RandomForestClassifier.pkl","wb"))

    return rf

# %%
 query = f"SELECT spectraldata.metadata_id, averaged_spectra, mandatorymetadata.sample_code  FROM spectraldata INNER JOIN mandatorymetadata ON mandatorymetadata.metadata_id = spectraldata.metadata_id WHERE is_finalized=True AND passed=True AND is_active=True AND averaged=True LIMIT 1000"
_ = pd.read_sql(query, con=conn)
_ = _.set_index("sample_code")
df = convertSpectra(_)
df.to_csv("input/spectraldata.csv")
split("D://Cropnuts/DSML141/input/spectraldata.csv",
          "D://Cropnuts/DSML141/input/rds/", "D://Cropnuts/DSML141/input/splits", "data")
sc = StandardScaler()
df_scaled = sc.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled,index=df.index,columns=df.columns)
df_quartiles = pd.DataFrame(index=df_scaled.index)
quartiles_dict = {}
for col in df_scaled.columns:
    lower = df_scaled[col].quantile(0.25)
    median = df_scaled[col].median()
    upper = df_scaled[col].quantile(0.75)
    quartiles_dict[col] = {
            "lower":lower,
            "median":median,
            "upper":upper
    }
    df_quartiles[col] =  df_scaled[col].apply(getCategory, args=( lower, median, upper))

train = pd.read_csv("input/splits/data_train_sample_codes.csv",index_col=1).index
test = pd.read_csv("input/splits/data_test_sample_codes.csv",index_col=1).index
valid = pd.read_csv("input/splits/data_valid_sample_codes.csv",index_col=1).index

X_train = df_quartiles.loc[df_quartiles.index.isin(train)]
X_test = df_quartiles.loc[df_quartiles.index.isin(test)]
X_valid = df_quartiles.loc[df_quartiles.index.isin(valid)]

y_train = np.random.randint(0,10, size=(len(X_train)))
y_test = np.random.randint(0,10, size=(len(X_test)))
y_valid = np.random.randint(0,10, size=(len(X_valid)))
# Out:
# C:\Python312\Lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
best_config = hyperparamTuning(X_valid, X_test, y_valid, y_test)
# Out:
# 2024-07-05 04:26:51,285	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-05 07:27:37</td></tr>
# <tr><td>Running for: </td><td>03:00:46.50        </td></tr>
# <tr><td>Memory:      </td><td>11.5/15.8 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name         </th><th>status  </th><th>loc  </th><th>criterion  </th><th style="text-align: right;">  max_depth</th><th>max_features  </th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  min_samples_split</th><th style="text-align: right;">  n_estimators</th></tr>
# </thead>
# <tbody>
# <tr><td>trainRF_a7ce0_00000</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         40</td><td>log2          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 40</td><td style="text-align: right;">           150</td></tr>
# <tr><td>trainRF_a7ce0_00001</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         20</td><td>log2          </td><td style="text-align: right;">                 7</td><td style="text-align: right;">                  5</td><td style="text-align: right;">            50</td></tr>
# <tr><td>trainRF_a7ce0_00002</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         10</td><td>log2          </td><td style="text-align: right;">                 6</td><td style="text-align: right;">                 15</td><td style="text-align: right;">           200</td></tr>
# <tr><td>trainRF_a7ce0_00003</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         40</td><td>              </td><td style="text-align: right;">                12</td><td style="text-align: right;">                  2</td><td style="text-align: right;">           250</td></tr>
# <tr><td>trainRF_a7ce0_00004</td><td>PENDING </td><td>     </td><td>entropy    </td><td style="text-align: right;">         20</td><td>log2          </td><td style="text-align: right;">                12</td><td style="text-align: right;">                 10</td><td style="text-align: right;">           100</td></tr>
# <tr><td>trainRF_a7ce0_00005</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         60</td><td>              </td><td style="text-align: right;">                 3</td><td style="text-align: right;">                  5</td><td style="text-align: right;">            50</td></tr>
# <tr><td>trainRF_a7ce0_00006</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">           </td><td>log2          </td><td style="text-align: right;">                 7</td><td style="text-align: right;">                 12</td><td style="text-align: right;">           100</td></tr>
# <tr><td>trainRF_a7ce0_00007</td><td>PENDING </td><td>     </td><td>gini       </td><td style="text-align: right;">           </td><td>              </td><td style="text-align: right;">                11</td><td style="text-align: right;">                 32</td><td style="text-align: right;">            50</td></tr>
# <tr><td>trainRF_a7ce0_00008</td><td>PENDING </td><td>     </td><td>entropy    </td><td style="text-align: right;">         20</td><td>sqrt          </td><td style="text-align: right;">                 4</td><td style="text-align: right;">                 36</td><td style="text-align: right;">            50</td></tr>
# <tr><td>trainRF_a7ce0_00009</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         50</td><td>sqrt          </td><td style="text-align: right;">                 5</td><td style="text-align: right;">                  5</td><td style="text-align: right;">           200</td></tr>
# <tr><td>trainRF_a7ce0_00010</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         60</td><td>              </td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 15</td><td style="text-align: right;">            50</td></tr>
# <tr><td>trainRF_a7ce0_00011</td><td>PENDING </td><td>     </td><td>gini       </td><td style="text-align: right;">         40</td><td>sqrt          </td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 36</td><td style="text-align: right;">           100</td></tr>
# <tr><td>trainRF_a7ce0_00012</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         10</td><td>sqrt          </td><td style="text-align: right;">                12</td><td style="text-align: right;">                 32</td><td style="text-align: right;">           150</td></tr>
# <tr><td>trainRF_a7ce0_00013</td><td>PENDING </td><td>     </td><td>gini       </td><td style="text-align: right;">         40</td><td>              </td><td style="text-align: right;">                 8</td><td style="text-align: right;">                 12</td><td style="text-align: right;">           250</td></tr>
# <tr><td>trainRF_a7ce0_00014</td><td>PENDING </td><td>     </td><td>entropy    </td><td style="text-align: right;">         50</td><td>sqrt          </td><td style="text-align: right;">                 9</td><td style="text-align: right;">                 15</td><td style="text-align: right;">           200</td></tr>
# <tr><td>trainRF_a7ce0_00015</td><td>PENDING </td><td>     </td><td>gini       </td><td style="text-align: right;">         50</td><td>log2          </td><td style="text-align: right;">                 4</td><td style="text-align: right;">                  5</td><td style="text-align: right;">           200</td></tr>
# <tr><td>trainRF_a7ce0_00016</td><td>PENDING </td><td>     </td><td>entropy    </td><td style="text-align: right;">           </td><td>              </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 15</td><td style="text-align: right;">           200</td></tr>
# <tr><td>trainRF_a7ce0_00017</td><td>PENDING </td><td>     </td><td>gini       </td><td style="text-align: right;">         60</td><td>              </td><td style="text-align: right;">                 6</td><td style="text-align: right;">                 36</td><td style="text-align: right;">           150</td></tr>
# <tr><td>trainRF_a7ce0_00018</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         20</td><td>log2          </td><td style="text-align: right;">                 8</td><td style="text-align: right;">                  5</td><td style="text-align: right;">           100</td></tr>
# <tr><td>trainRF_a7ce0_00019</td><td>PENDING </td><td>     </td><td>gini       </td><td style="text-align: right;">         20</td><td>log2          </td><td style="text-align: right;">                 9</td><td style="text-align: right;">                 10</td><td style="text-align: right;">           200</td></tr>
# <tr><td>trainRF_a7ce0_00020</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">           </td><td>log2          </td><td style="text-align: right;">                 6</td><td style="text-align: right;">                  2</td><td style="text-align: right;">           100</td></tr>
# <tr><td>trainRF_a7ce0_00021</td><td>PENDING </td><td>     </td><td>log_loss   </td><td style="text-align: right;">         60</td><td>sqrt          </td><td style="text-align: right;">                 7</td><td style="text-align: right;">                 40</td><t
# 2024-07-05 04:26:51,773	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00000_0_criterion=log_loss,max_depth=40,max_features=log2,min_samples_leaf=1,min_samples_split=40,n_estimators=150_2024-07-05_04-26-51
# 2024-07-05 04:26:51,778	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00000_0_criterion=log_loss,max_depth=40,max_features=log2,min_samples_leaf=1,min_samples_split=40,n_estimators=150_2024-07-05_04-26-51
# 2024-07-05 04:26:51,783	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00001_1_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=7,min_samples_split=5,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,786	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00001_1_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=7,min_samples_split=5,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,791	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00002_2_criterion=log_loss,max_depth=10,max_features=log2,min_samples_leaf=6,min_samples_split=15,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,791	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00002_2_criterion=log_loss,max_depth=10,max_features=log2,min_samples_leaf=6,min_samples_split=15,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,802	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00003_3_criterion=log_loss,max_depth=40,max_features=None,min_samples_leaf=12,min_samples_split=2,n_estimators=250_2024-07-05_04-26-51
# 2024-07-05 04:26:51,806	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00003_3_criterion=log_loss,max_depth=40,max_features=None,min_samples_leaf=12,min_samples_split=2,n_estimators=250_2024-07-05_04-26-51
# 2024-07-05 04:26:51,813	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00004_4_criterion=entropy,max_depth=20,max_features=log2,min_samples_leaf=12,min_samples_split=10,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,816	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00004_4_criterion=entropy,max_depth=20,max_features=log2,min_samples_leaf=12,min_samples_split=10,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,822	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00005_5_criterion=log_loss,max_depth=60,max_features=None,min_samples_leaf=3,min_samples_split=5,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,826	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00005_5_criterion=log_loss,max_depth=60,max_features=None,min_samples_leaf=3,min_samples_split=5,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,832	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00006_6_criterion=log_loss,max_depth=None,max_features=log2,min_samples_leaf=7,min_samples_split=12,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,835	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00006_6_criterion=log_loss,max_depth=None,max_features=log2,min_samples_leaf=7,min_samples_split=12,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,841	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00007_7_criterion=gini,max_depth=None,max_features=None,min_samples_leaf=11,min_samples_split=32,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,843	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00007_7_criterion=gini,max_depth=None,max_features=None,min_samples_leaf=11,min_samples_split=32,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,849	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00008_8_criterion=entropy,max_depth=20,max_features=sqrt,min_samples_leaf=4,min_samples_split=36,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,853	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00008_8_criterion=entropy,max_depth=20,max_features=sqrt,min_samples_leaf=4,min_samples_split=36,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,858	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00009_9_criterion=log_loss,max_depth=50,max_features=sqrt,min_samples_leaf=5,min_samples_split=5,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,861	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00009_9_criterion=log_loss,max_depth=50,max_features=sqrt,min_samples_leaf=5,min_samples_split=5,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,868	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00010_10_criterion=log_loss,max_depth=60,max_features=None,min_samples_leaf=5,min_samples_split=15,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,871	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00010_10_criterion=log_loss,max_depth=60,max_features=None,min_samples_leaf=5,min_samples_split=15,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,879	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00011_11_criterion=gini,max_depth=40,max_features=sqrt,min_samples_leaf=5,min_samples_split=36,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,883	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00011_11_criterion=gini,max_depth=40,max_features=sqrt,min_samples_leaf=5,min_samples_split=36,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,890	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00012_12_criterion=log_loss,max_depth=10,max_features=sqrt,min_samples_leaf=12,min_samples_split=32,n_estimators=150_2024-07-05_04-26-51
# 2024-07-05 04:26:51,893	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00012_12_criterion=log_loss,max_depth=10,max_features=sqrt,min_samples_leaf=12,min_samples_split=32,n_estimators=150_2024-07-05_04-26-51
# 2024-07-05 04:26:51,898	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00013_13_criterion=gini,max_depth=40,max_features=None,min_samples_leaf=8,min_samples_split=12,n_estimators=250_2024-07-05_04-26-51
# 2024-07-05 04:26:51,901	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00013_13_criterion=gini,max_depth=40,max_features=None,min_samples_leaf=8,min_samples_split=12,n_estimators=250_2024-07-05_04-26-51
# 2024-07-05 04:26:51,908	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00014_14_criterion=entropy,max_depth=50,max_features=sqrt,min_samples_leaf=9,min_samples_split=15,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,911	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00014_14_criterion=entropy,max_depth=50,max_features=sqrt,min_samples_leaf=9,min_samples_split=15,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,917	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00015_15_criterion=gini,max_depth=50,max_features=log2,min_samples_leaf=4,min_samples_split=5,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,920	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00015_15_criterion=gini,max_depth=50,max_features=log2,min_samples_leaf=4,min_samples_split=5,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,926	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00016_16_criterion=entropy,max_depth=None,max_features=None,min_samples_leaf=1,min_samples_split=15,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,929	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00016_16_criterion=entropy,max_depth=None,max_features=None,min_samples_leaf=1,min_samples_split=15,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,934	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00017_17_criterion=gini,max_depth=60,max_features=None,min_samples_leaf=6,min_samples_split=36,n_estimators=150_2024-07-05_04-26-51
# 2024-07-05 04:26:51,937	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00017_17_criterion=gini,max_depth=60,max_features=None,min_samples_leaf=6,min_samples_split=36,n_estimators=150_2024-07-05_04-26-51
# 2024-07-05 04:26:51,943	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00018_18_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=8,min_samples_split=5,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,945	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00018_18_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=8,min_samples_split=5,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,951	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00019_19_criterion=gini,max_depth=20,max_features=log2,min_samples_leaf=9,min_samples_split=10,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,954	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00019_19_criterion=gini,max_depth=20,max_features=log2,min_samples_leaf=9,min_samples_split=10,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,961	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00020_20_criterion=log_loss,max_depth=None,max_features=log2,min_samples_leaf=6,min_samples_split=2,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,965	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00020_20_criterion=log_loss,max_depth=None,max_features=log2,min_samples_leaf=6,min_samples_split=2,n_estimators=100_2024-07-05_04-26-51
# 2024-07-05 04:26:51,972	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00021_21_criterion=log_loss,max_depth=60,max_features=sqrt,min_samples_leaf=7,min_samples_split=40,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,975	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00021_21_criterion=log_loss,max_depth=60,max_features=sqrt,min_samples_leaf=7,min_samples_split=40,n_estimators=50_2024-07-05_04-26-51
# 2024-07-05 04:26:51,981	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00022_22_criterion=log_loss,max_depth=40,max_features=log2,min_samples_leaf=3,min_samples_split=2,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,984	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00022_22_criterion=log_loss,max_depth=40,max_features=log2,min_samples_leaf=3,min_samples_split=2,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,994	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00023_23_criterion=gini,max_depth=30,max_features=sqrt,min_samples_leaf=13,min_samples_split=12,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:51,996	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00023_23_criterion=gini,max_depth=30,max_features=sqrt,min_samples_leaf=13,min_samples_split=12,n_estimators=200_2024-07-05_04-26-51
# 2024-07-05 04:26:52,002	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00024_24_criterion=gini,max_depth=40,max_features=log2,min_samples_leaf=12,min_samples_split=12,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,006	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00024_24_criterion=gini,max_depth=40,max_features=log2,min_samples_leaf=12,min_samples_split=12,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,011	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00025_25_criterion=entropy,max_depth=50,max_features=sqrt,min_samples_leaf=5,min_samples_split=36,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,014	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00025_25_criterion=entropy,max_depth=50,max_features=sqrt,min_samples_leaf=5,min_samples_split=36,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,018	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00026_26_criterion=log_loss,max_depth=30,max_features=log2,min_samples_leaf=1,min_samples_split=12,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,021	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00026_26_criterion=log_loss,max_depth=30,max_features=log2,min_samples_leaf=1,min_samples_split=12,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,026	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00027_27_criterion=gini,max_depth=30,max_features=sqrt,min_samples_leaf=14,min_samples_split=36,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,029	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00027_27_criterion=gini,max_depth=30,max_features=sqrt,min_samples_leaf=14,min_samples_split=36,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,035	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00028_28_criterion=gini,max_depth=10,max_features=log2,min_samples_leaf=14,min_samples_split=5,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,038	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00028_28_criterion=gini,max_depth=10,max_features=log2,min_samples_leaf=14,min_samples_split=5,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,045	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00029_29_criterion=entropy,max_depth=40,max_features=log2,min_samples_leaf=4,min_samples_split=15,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,047	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00029_29_criterion=entropy,max_depth=40,max_features=log2,min_samples_leaf=4,min_samples_split=15,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,053	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00030_30_criterion=log_loss,max_depth=10,max_features=None,min_samples_leaf=14,min_samples_split=15,n_estimators=200_2024-07-05_04-26-52
# 2024-07-05 04:26:52,056	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00030_30_criterion=log_loss,max_depth=10,max_features=None,min_samples_leaf=14,min_samples_split=15,n_estimators=200_2024-07-05_04-26-52
# 2024-07-05 04:26:52,063	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00031_31_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=1,min_samples_split=2,n_estimators=50_2024-07-05_04-26-52
# 2024-07-05 04:26:52,065	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00031_31_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=1,min_samples_split=2,n_estimators=50_2024-07-05_04-26-52
# 2024-07-05 04:26:52,074	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00032_32_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=14,min_samples_split=5,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,078	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00032_32_criterion=log_loss,max_depth=20,max_features=log2,min_samples_leaf=14,min_samples_split=5,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,086	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00033_33_criterion=log_loss,max_depth=60,max_features=sqrt,min_samples_leaf=3,min_samples_split=10,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,089	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00033_33_criterion=log_loss,max_depth=60,max_features=sqrt,min_samples_leaf=3,min_samples_split=10,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,095	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00034_34_criterion=gini,max_depth=10,max_features=sqrt,min_samples_leaf=8,min_samples_split=36,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,097	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00034_34_criterion=gini,max_depth=10,max_features=sqrt,min_samples_leaf=8,min_samples_split=36,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,104	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00035_35_criterion=gini,max_depth=50,max_features=log2,min_samples_leaf=1,min_samples_split=2,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,106	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00035_35_criterion=gini,max_depth=50,max_features=log2,min_samples_leaf=1,min_samples_split=2,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,111	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00036_36_criterion=gini,max_depth=None,max_features=None,min_samples_leaf=2,min_samples_split=12,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,126	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00036_36_criterion=gini,max_depth=None,max_features=None,min_samples_leaf=2,min_samples_split=12,n_estimators=150_2024-07-05_04-26-52
# 2024-07-05 04:26:52,157	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00037_37_criterion=gini,max_depth=None,max_features=None,min_samples_leaf=11,min_samples_split=32,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,166	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00037_37_criterion=gini,max_depth=None,max_features=None,min_samples_leaf=11,min_samples_split=32,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,174	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00038_38_criterion=log_loss,max_depth=40,max_features=None,min_samples_leaf=2,min_samples_split=5,n_estimators=200_2024-07-05_04-26-52
# 2024-07-05 04:26:52,177	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00038_38_criterion=log_loss,max_depth=40,max_features=None,min_samples_leaf=2,min_samples_split=5,n_estimators=200_2024-07-05_04-26-52
# 2024-07-05 04:26:52,182	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00039_39_criterion=entropy,max_depth=30,max_features=None,min_samples_leaf=13,min_samples_split=32,n_estimators=50_2024-07-05_04-26-52
# 2024-07-05 04:26:52,188	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00039_39_criterion=entropy,max_depth=30,max_features=None,min_samples_leaf=13,min_samples_split=32,n_estimators=50_2024-07-05_04-26-52
# 2024-07-05 04:26:52,194	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00040_40_criterion=entropy,max_depth=50,max_features=None,min_samples_leaf=13,min_samples_split=15,n_estimators=100_2024-07-05_04-26-52
# 2024-07-05 04:26:52,196	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00040_40_criterion=entropy,max_depth=50,max_features=None,min_samples_leaf=13,min_samples_split=15,n_estimators=100_2024-07-05_04-26-52
# ...
# 2024-07-05 04:26:53,326	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00184_184_criterion=entropy,max_depth=10,max_features=sqrt,min_samples_leaf=12,min_samples_split=12,n_estimators=250_2024-07-05_04-26-53
# 2024-07-05 04:26:53,328	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00184_184_criterion=entropy,max_depth=10,max_features=sqrt,min_samples_leaf=12,min_samples_split=12,n_estimators=250_2024-07-05_04-26-53
# 2024-07-05 04:26:53,334	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00185_185_criterion=entropy,max_depth=40,max_features=sqrt,min_samples_leaf=6,min_samples_split=10,n_estimators=200_2024-07-05_04-26-53
# 2024-07-05 04:26:53,336	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00185_185_criterion=entropy,max_depth=40,max_features=sqrt,min_samples_leaf=6,min_samples_split=10,n_estimators=200_2024-07-05_04-26-53
# 2024-07-05 04:26:53,341	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00186_186_criterion=gini,max_depth=50,max_features=log2,min_samples_leaf=9,min_samples_split=20,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,343	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00186_186_criterion=gini,max_depth=50,max_features=log2,min_samples_leaf=9,min_samples_split=20,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,348	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00187_187_criterion=entropy,max_depth=10,max_features=None,min_samples_leaf=4,min_samples_split=20,n_estimators=250_2024-07-05_04-26-53
# 2024-07-05 04:26:53,350	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00187_187_criterion=entropy,max_depth=10,max_features=None,min_samples_leaf=4,min_samples_split=20,n_estimators=250_2024-07-05_04-26-53
# 2024-07-05 04:26:53,355	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00188_188_criterion=gini,max_depth=30,max_features=sqrt,min_samples_leaf=4,min_samples_split=2,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,359	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00188_188_criterion=gini,max_depth=30,max_features=sqrt,min_samples_leaf=4,min_samples_split=2,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,359	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00189_189_criterion=gini,max_depth=10,max_features=log2,min_samples_leaf=7,min_samples_split=20,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,366	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00189_189_criterion=gini,max_depth=10,max_features=log2,min_samples_leaf=7,min_samples_split=20,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,371	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00190_190_criterion=entropy,max_depth=60,max_features=sqrt,min_samples_leaf=10,min_samples_split=20,n_estimators=100_2024-07-05_04-26-53
# 2024-07-05 04:26:53,373	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00190_190_criterion=entropy,max_depth=60,max_features=sqrt,min_samples_leaf=10,min_samples_split=20,n_estimators=100_2024-07-05_04-26-53
# 2024-07-05 04:26:53,377	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00191_191_criterion=log_loss,max_depth=60,max_features=log2,min_samples_leaf=7,min_samples_split=12,n_estimators=100_2024-07-05_04-26-53
# 2024-07-05 04:26:53,380	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00191_191_criterion=log_loss,max_depth=60,max_features=log2,min_samples_leaf=7,min_samples_split=12,n_estimators=100_2024-07-05_04-26-53
# 2024-07-05 04:26:53,384	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00192_192_criterion=gini,max_depth=50,max_features=None,min_samples_leaf=4,min_samples_split=15,n_estimators=100_2024-07-05_04-26-53
# 2024-07-05 04:26:53,386	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00192_192_criterion=gini,max_depth=50,max_features=None,min_samples_leaf=4,min_samples_split=15,n_estimators=100_2024-07-05_04-26-53
# 2024-07-05 04:26:53,391	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00193_193_criterion=log_loss,max_depth=10,max_features=sqrt,min_samples_leaf=6,min_samples_split=40,n_estimators=250_2024-07-05_04-26-53
# 2024-07-05 04:26:53,393	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00193_193_criterion=log_loss,max_depth=10,max_features=sqrt,min_samples_leaf=6,min_samples_split=40,n_estimators=250_2024-07-05_04-26-53
# 2024-07-05 04:26:53,398	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00194_194_criterion=log_loss,max_depth=20,max_features=sqrt,min_samples_leaf=9,min_samples_split=15,n_estimators=150_2024-07-05_04-26-53
# 2024-07-05 04:26:53,401	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00194_194_criterion=log_loss,max_depth=20,max_features=sqrt,min_samples_leaf=9,min_samples_split=15,n_estimators=150_2024-07-05_04-26-53
# 2024-07-05 04:26:53,405	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00195_195_criterion=entropy,max_depth=20,max_features=sqrt,min_samples_leaf=6,min_samples_split=32,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,408	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00195_195_criterion=entropy,max_depth=20,max_features=sqrt,min_samples_leaf=6,min_samples_split=32,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,412	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00196_196_criterion=entropy,max_depth=40,max_features=sqrt,min_samples_leaf=10,min_samples_split=20,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,415	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00196_196_criterion=entropy,max_depth=40,max_features=sqrt,min_samples_leaf=10,min_samples_split=20,n_estimators=50_2024-07-05_04-26-53
# 2024-07-05 04:26:53,419	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00197_197_criterion=entropy,max_depth=60,max_features=sqrt,min_samples_leaf=6,min_samples_split=12,n_estimators=200_2024-07-05_04-26-53
# 2024-07-05 04:26:53,422	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00197_197_criterion=entropy,max_depth=60,max_features=sqrt,min_samples_leaf=6,min_samples_split=12,n_estimators=200_2024-07-05_04-26-53
# 2024-07-05 04:26:53,426	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00198_198_criterion=entropy,max_depth=60,max_features=log2,min_samples_leaf=7,min_samples_split=32,n_estimators=150_2024-07-05_04-26-53
# 2024-07-05 04:26:53,428	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00198_198_criterion=entropy,max_depth=60,max_features=log2,min_samples_leaf=7,min_samples_split=32,n_estimators=150_2024-07-05_04-26-53
# 2024-07-05 04:26:53,433	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00199_199_criterion=log_loss,max_depth=60,max_features=log2,min_samples_leaf=13,min_samples_split=12,n_estimators=10_2024-07-05_04-26-53
# 2024-07-05 04:26:53,435	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\tommy\AppData\Local\Temp\ray\session_2024-07-05_04-24-11_703299_7056\artifacts\2024-07-05_04-26-51\trainRF_2024-07-05_04-26-51\driver_artifacts\trainRF_a7ce0_00199_199_criterion=log_loss,max_depth=60,max_features=log2,min_samples_leaf=13,min_samples_split=12,n_estimators=10_2024-07-05_04-26-53
# 2024-07-05 07:27:24,682	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-07-05 07:27:37,798	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to 'C:/Users/tommy/ray_results/trainRF_2024-07-05_04-26-51' in 13.1164s.

# %%
df_validated_subtypes = getSampleCodes()

# %%
train=[]
test=[]
valid=[]
for i in df_validated_subtypes.validated_subtype.unique():
    subtype_sample_codes = df_validated_subtypes.loc[df_validated_subtypes['validated_subtype'] == i]
    subtype_spc = getValidAver(subtype_sample_codes['sample_code'],filename=i)
    split(f"D://Cropnuts/DSML155/input/{i}.csv",
          "D://Cropnuts/DSML155/input/rds/", "D://Cropnuts/DSML155/input/splits", i)
    train.extend([i for i in pd.read(f"{i}_train_sample_codes.csv",index_col=1).index])
    test.extend([i for i in pd.read(f"{i}_test_sample_codes.csv",index_col=1).index])
    valid.extend([i for i in pd.read(f"{i}_valid_sample_codes.csv",index_col=1).index])
# Out:
# pandas.core.indexes.base.Index

# %%
le = LabelEncoder()
y = le.fit_transform(df_validated_subtypes.validated_subtype)
pickle.dump(le, open("output/target_le.pkl","wb"))

# %%
spc = getValidAver(df_validated_subtypes['sample_code'])

# %%
sc = StandardScaler()
spc_scaled = sc.fit_transform(spc)
spc_scaled = pd.DataFrame(spc_scaled, index=spc.index, columns=spc.columns)
pickle.dump(sc, open("output/feature_scaler.pkl","wb"))

# %%
spc_quartiles = pd.DataFrame(index=spc_scaled.index)
quartiles_dict = {}
for col in spc_scaled.columns:
    lower = spc_scaled[col].quantile(0.25)
    median = spc_scaled[col].median()
    upper = spc_scaled[col].quantile(0.75)
    quartiles_dict[col] = {
            "lower":lower,
            "median":median,
            "upper":upper
    }
    spc_quartiles[col] =  spc_scaled[col].apply(getCategory, args=( lower, median, upper))
pickle.dump(quartiles_dict, open("output/absorbance_quartiles.dict","wb"))

# %%
X_train = spc_quartiles.loc[spc_quartiles.index.isin(train)]
X_test = spc_quartiles.loc[spc_quartiles.index.isin(test)]
X_valid = spc_quartiles.loc[spc_quartiles.index.isin(valid)]

y_train = y.loc[spc_quartiles.index.isin(train)]
y_test = y.loc[spc_quartiles.index.isin(test)]
y_valid = y.loc[spc_quartiles.index.isin(valid)]

# %%
best_config = hyperparamTuning(X_valid, X_test, y_valid, y_test)

# %%
clf = trainRFClassifier(best_config, X_train, y_train)
